# %%
# %%capture
# !pip install diffusers transformers accelerate scipy safetensors

# %%
from diffusers import DiffusionPipeline, EulerDiscreteScheduler
import torch
import matplotlib.pyplot as plt

pipe = DiffusionPipeline.from_pretrained("/kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1", torch_dtype=torch.float16, use_safetensors=True, variant="fp16")
pipe.to("cuda")
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# StableDiffusionXLPipeline {
#   "_class_name": "StableDiffusionXLPipeline",
#   "_diffusers_version": "0.25.0",
#   "_name_or_path": "/kaggle/input/stable-diffusion-xl/pytorch/base-1-0/1",
#   "feature_extractor": [
#     null,
#     null
#   ],
#   "force_zeros_for_empty_prompt": true,
#   "image_encoder": [
#     null,
#     null
#   ],
#   "scheduler": [
#     "diffusers",
#     "EulerDiscreteScheduler"
#   ],
# ...

# %%
def generate(prompt):
    return pipe(prompt=prompt).images[0]

# %%
prompt = "A Gurkha soildier proudly demonstrating his Khukuri!"
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A digital illustration of a space station orbiting a distant planet, with futuristic technology and vibrant colors."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "An otherworldly landscape with floating islands, alien flora, and a mesmerizing sky."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A medieval castle shrouded in mist, with torches lighting the way and a sense of mystery in the air."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A cozy cabin in the woods, with a crackling fireplace, warm lighting, and a serene atmosphere."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "An epic fantasy battle scene with mythical creatures, heroic warriors, and dramatic lighting."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A bustling cyberpunk cityscape, with neon lights, futuristic skyscrapers, and a sense of constant motion."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A tranquil garden in full bloom, with vibrant flowers, winding paths, and a feeling of peace and harmony."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "An underwater world teeming with colorful marine life, coral reefs, and rays of sunlight piercing the depths."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A post-apocalyptic wasteland, with desolate ruins, ominous skies, and a feeling of survival against all odds."
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt = "A whimsical steampunk carnival, with elaborate contraptions, eccentric characters, and a sense of wonder and adventure"
plt.imshow(generate(prompt))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
